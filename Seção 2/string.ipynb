# %%
nome = "Marcos"
idade = 25

mensagem = "Meu nome é {} e tenho {} anos".format(nome, idade)
print(mensagem)
# Out:
# Meu nome é Marcos e tenho 25 anos

# %%
mensagem = "Aluno: {0} | Idade: {1}".format("Ana", 22)
print(mensagem)
# Out:
# Aluno: Ana | Idade: Ana

# %%
nome = "Python"

print(f"|{nome:<10}|")  # esquerda
print(f"|{nome:>10}|")  # direita
print(f"|{nome:^10}|")  # centro
# Out:
# |Python    |
# |    Python|
# |  Python  |

# %%
x = 42
y = 7

print(f"{x=}, {y=}")
# Out:
# x=42, y=7
