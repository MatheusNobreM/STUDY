# %%
num = [5, 15, 3, 2, 40, 50]

# %%
#Filtrar e armazenar números maiores q 10
num_mariores_q_10 = [n for n in num if(maior := n) > 10]
num_mariores_q_10
# Out:
# [15, 40, 50]

# %%
linhas_processadas = []

with open("txt.txt", "r", encoding="utf-8") as arq:
  for linha in arq:
    if(linha_limpa := linha.strip()):
      linhas_processadas.append(linha_limpa)

# %%
linhas_processadas
# Out:
# ['ola mundo', 'hello le', 'python teste', 'ruby on ruby']
