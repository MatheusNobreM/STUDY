# %%
frutas = ["Maça", "banana", "laranja"]
nums = [10, 20, 30]

# %%
for num,fruta in zip(nums, frutas):
  print(f"Numero: {num}, Fruta {fruta}")
# Out:
# Numero: 10, Fruta Maça
# Numero: 20, Fruta banana
# Numero: 30, Fruta laranja
