# %%
def numeros_impares2(n):
  for i in range(1, n+1, 2):
    yield i

# %%
def numeros_impares(n):
  for i in range(1, n+1, 2):
    return i

# %%
for numero in numeros_impares(10):
  print(numero)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 for numero in numeros_impares(10):
#       2   print(numero)
#
# TypeError: 'int' object is not iterable

# %%
for numero in numeros_impares2(10):
  print(numero)
# Out:
# 1
# 3
# 5
# 7
# 9
